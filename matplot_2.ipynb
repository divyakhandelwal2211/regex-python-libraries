# %%
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots()
Movie_type = ['comedy','action','romance','drama','scifi']
Responses = [4,5,6,1,4]

ax.bar(Movie_type,Responses)
ax.bar(Movie_type,Responses)
ax.set_ylabel("survey responses")
ax.set_xlabel("movie_type")
ax.set_title("MOVIES")

ax.set_xticklabels(Movie_type,rotation=30)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21608\3495982418.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(Movie_type,rotation=30)

# %%
statistics.stdev(Responses)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 statistics.stdev(Responses)
#
# NameError: name 'statistics' is not defined
